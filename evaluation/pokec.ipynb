# %%
import pickle 
import numpy as np
with open("case-study/telecom-novi/telecom_static.pkl","rb+") as f:
    data_ytb = pickle.loads(f.read()) 
# with open("case-study/naive/telecom/telecom_naive_static.pkl","rb+") as f:
#     data_ytb1 = pickle.loads(f.read()) 

for i in data_ytb:
    a = len(list(filter(lambda x: x > 30000, i[2])))
    if a > 0:
        print(f"{i[1]}: {a}")

# for i in data_ytb1:
#     print(f"{i[1]}:{len(list(filter(lambda x: x > 10000, i[2])))}")

# %%
import pickle 
import numpy as np
with open("case-study/telecom-novi/telecom_static.pkl","rb+") as f:
    data_ytb = pickle.loads(f.read()) 


for i in data_ytb:
    print(f"{i[1]} query, the max time is {format(np.max(i[2]),'.3f')} ms, the average time is {format(np.mean(i[2]),'.3f')} ms, and the variance is {format(np.var(list(map(lambda x: x/1000, i[2]))),'.3f')}")
# Out:
# REGEX Q0 query, the max time is 17.415 ms, the average time is 0.337 ms, and the variance is 0.000
# RDPQ Q11 query, the max time is 294.599 ms, the average time is 16.186 ms, and the variance is 0.002
# RDPQ Q12 query, the max time is 6.542 ms, the average time is 4.507 ms, and the variance is 0.000
# RDPQ Q13 query, the max time is 8.945 ms, the average time is 4.815 ms, and the variance is 0.000
# RDPQ Q14 query, the max time is 199.264 ms, the average time is 41.791 ms, and the variance is 0.003
# RDPQ Q15 query, the max time is 230.040 ms, the average time is 20.762 ms, and the variance is 0.001
# REGEX Q1 query, the max time is 15.972 ms, the average time is 0.405 ms, and the variance is 0.000
# RDPQ Q21 query, the max time is 46.090 ms, the average time is 6.558 ms, and the variance is 0.000
# RDPQ Q22 query, the max time is 14.533 ms, the average time is 4.728 ms, and the variance is 0.000
# ...

# %% [markdown]
# """
# This is the parameterized regex of dating query:
#
# (people {?p == AGE and ?x == completion_percentage and ?g == gender})/ ((:follow {true})/(people {true}))*/(:follow {true}) /
#         (people {
#                ?p * 0.5 + 7 <= AGE
#                and  ?x - completion_percentage <= 50  and
#                completion_percentage - ?x <= 50 and
#               ?g == gender
#                })
# """

# %%
import matplotlib.pyplot as plt 
plt.title("Dating Query for the Pokec Graph",loc='right')
max = np.max(data_ytb[0][2])
plt.hist(data_ytb[0][2], bins=30, log=True)
ax = plt.subplot()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.xlabel("The Running Time (ms)")
plt.ylabel("The Numbers of Queries", labelpad=-40, y =1.02, rotation=0)
# Out:
# Text(0, 1.02, 'The Numbers of Queries')

# %% [markdown]
# This is the regex of money query:
#
# (people {?p - ?q < 30 and ?p > AGE and ?q < AGE})/ ((:follow {true}) /(people { ?p - ?q < 30 and ?p > AGE and ?q < AGE }))+

# %%
import matplotlib.pyplot as plt 
plt.title("Money Query for the Pokec Graph",loc='right')
max = np.max(data_ytb[1][2])
plt.hist(data_ytb[1][2], bins=30, log=True)
ax = plt.subplot()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.xlabel("The Running Time (ms)")
plt.ylabel("The Numbers of Queries", labelpad=-40, y =1.02, rotation=0)
# Out:
# Text(0, 1.02, 'The Numbers of Queries')

# %% [markdown]
# This is the original central path query:
#
# (people {
#  (?x - completion_percentage) + (?y - AGE) <= 35 and
#     (?x - completion_percentage) + (AGE - ?y) <= 35 and
#     (completion_percentage - ?x) + (?y - AGE) <= 35 and
#     (completion_percentage - ?x) + (AGE - ?y) <= 35
# })/ ((:follow {true}) /(people {
#     (?x - completion_percentage) + (?y - AGE) <= 35 and
#     (?x - completion_percentage) + (AGE - ?y) <= 35 and
#     (completion_percentage - ?x) + (?y - AGE) <= 35 and
#     (completion_percentage - ?x) + (AGE - ?y) <= 35
# }))+

# %%
import matplotlib.pyplot as plt 
plt.title("Central Path for the Pokec Graph",loc='right')
max = np.max(data_ytb[2][2])
plt.hist(data_ytb[2][2], bins=30, log=True)
ax = plt.subplot()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.xlabel("The Running Time (ms)")
plt.ylabel("The Numbers of Queries", labelpad=-40, y =1.02, rotation=0)
# Out:
# Text(0, 1.02, 'The Numbers of Queries')

# %% [markdown]
# This variant, I add more plus operator to query longer paths:
#
#
# (people {
#     (?x - completion_percentage)  <= 35 and
#     (AGE - ?y) <= 20 and
#     (?y - AGE) <= 20 and
#     (completion_percentage - ?x)  <= 35
# })/ ((:follow {true}) /(people {
#     (?x - completion_percentage)  <= 35 and
#     (AGE - ?y) <= 20 and
#     (?y - AGE) <= 20 and
#     (completion_percentage - ?x)  <= 35
# }))+ / (:follow {true}) /(people {
#     (?x - completion_percentage)  <= 35 and
#     (AGE - ?y) <= 20 and
#     (?y - AGE) <= 20 and
#     (completion_percentage - ?x)  <= 35
# })

# %%
import matplotlib.pyplot as plt 
plt.title("Longer Central Path for the Pokec Graph",loc='right')
max = np.max(data_ytb[3][2])
plt.hist(data_ytb[3][2], bins=30, log=True)
ax = plt.subplot()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.xlabel("The Running Time (ms)")
plt.ylabel("The Numbers of Queries", labelpad=-40, y =1.02, rotation=0)
# Out:
# Text(0, 1.02, 'The Numbers of Queries')

# %% [markdown]
# And then I also add alternations:
#
#
# ((people {
#     (?y - AGE) <= 20 and
#     (AGE - ?y) <= 20
# })/ ((:follow {true}) /(people {
#      (?y - AGE) <= 20 and
#     (AGE - ?y) <= 20
# }))+) | (people {
#     (?x - completion_percentage)  <= 35 and
#
#     (completion_percentage - ?x)  <= 35
# })/ ((:follow {true}) /(people {
#     (?x - completion_percentage)  <= 35 and
#
#     (completion_percentage - ?x)  <= 35
# }))*

# %%
import matplotlib.pyplot as plt 
plt.title("Central Path with Alter for the Pokec Graph",loc='right')
max = np.max(data_ytb[4][2])
plt.hist(data_ytb[4][2], bins=30, log=True)
ax = plt.subplot()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.xlabel("The Running Time (ms)")
plt.ylabel("The Numbers of Queries", labelpad=-40, y =1.02, rotation=0)
# Out:
# Text(0, 1.02, 'The Numbers of Queries')

# %% [markdown]
# Actually I failed with this case, because this case took too much time. Finally I finished around 16k cases. The reason is that {3,4} quantifier produces a very large alternation of "?" quantifiers, and then have the regex and the automaton very large
#
# ((people {
#     (?y - AGE) <= 20 and
#     (AGE - ?y) <= 20
# })/ ((:follow {true}) /(people {
#      (?y - AGE) <= 20 and
#     (AGE - ?y) <= 20
# })){3,4}) | (people {
#     (?x - completion_percentage)  <= 35 and
#
#     (completion_percentage - ?x)  <= 35
# })/ ((:follow {true}) /(people {
#     (?x - completion_percentage)  <= 35 and
#
#     (completion_percentage - ?x)  <= 35
# })){3,4}

# %%
import matplotlib.pyplot as plt 
plt.title("Central Path with Alter for the Pokec Graph",loc='right')
plt.hist(data_ytb[5][2], bins=30, log=True)
ax = plt.subplot()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.xlabel("The Running Time (ms)")
plt.ylabel("The Numbers of Queries", labelpad=-40, y =1.02, rotation=0)
# Out:
# Text(0, 1.02, 'The Numbers of Queries')
